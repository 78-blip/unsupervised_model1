# %% [markdown]
# <a href="https://colab.research.google.com/github/78-blip/capsone-project/blob/main1/Copy_of_Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# **name**       -MOHINI SHARMA

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# Here by ,i will bw working on the data set related to hotel bookings and its analysis in various variables upon which ,a useful conclusion will be drawn ⁉
#
# :using graphs and charts ,useful indights will be made
#
# :bookings for the particular time shall be analysed.
#
# :the base of my project
#  will be to use the acquired knowledge
#  of dataset and fetch workings and swot analysis ,
#  and make plans for same.
#
# : the project is to direct my efforts to make a gist of  important parameters.
#
# :i will bw adjusting the data to need
#
# :data will be trandformed into structured information to use,

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# define business oblective

# %% [markdown]
# Answer Here.
#
# My business objective is to draw useful insights from the given dataset in order to make better decisions,these will include the following steps which are to take place throughout my project:
#
# :to draw useful charts and graphs which will itself show and visualise the important variable.
#
# :to filter useful data and make resuklt out of it
#
# :to make plans and policies out of data and working on it further.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
#load dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
work_path='/content/drive/MyDrive/Hotel Bookings.csv'
imdb_df=pd.read_csv(work_path)
imdb_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
imdb_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
imdb_df.duplicated
# Out:
# <bound method DataFrame.duplicated of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
imdb_df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
imdb_df['company']=='isna'
imdb_df['agent']=='isna'
imdb_df['country']=='isna'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Name: country, Length: 119390, dtype: bool

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
# Hereby i know that the given dataset is all about :
#
# :Hotel bookings in particular time period
#
# :types of customers
#
# :bookings in different months
#
# :bookings in different room types
#
# :types of hotels
#
# :stays in week,and weekends
#
# :customer type
#
# ;deposit
#
# :parking space used by clients

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
imdb_df.columns.values
# Out:
# array(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'], dtype=object)

# %%
# Dataset Describe
imdb_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here
#
# Here various kind of variables are given in data set which signifies various parameters of booking and related info.like:
#
# hotel',    'is_canceled',   'lead_time',    'arrival_date_year',
#        'arrival_date_month'  , 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

#filtering columns to work on
mydf=imdb_df[['hotel', 'lead_time', 'arrival_date_year',
       'arrival_date_month', 'arrival_date_week_number',
       'arrival_date_day_of_month', 'stays_in_weekend_nights',
       'stays_in_week_nights', 'adults', 'children', 'babies', 
       'country',
       'is_repeated_guest', 'reserved_room_type',
       'assigned_room_type']]
       #creating a unique id for every noted booking for counting
mydf
mydf['unique_id']=range(1,119391)
mydf.head()
# Out:
# <ipython-input-13-7f23309c15c1>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf['unique_id']=range(1,119391)
#           hotel  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel        342               2015               July
# 1  Resort Hotel        737               2015               July
# 2  Resort Hotel          7               2015               July
# 3  Resort Hotel         13               2015               July
# 4  Resort Hotel         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
#
# I have filtered the data ⁉
#
#  i have created a new unique id as a new variable to store every booking uniquely in order to fecilitate counting,,from the dataset so as to make it more informative.
#
# ,i have filtered important variables on which i will be working .

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# counting the number of transactions for each hotel type

types_of_hotel_bookings=mydf.groupby('hotel')['unique_id'].count()
plotting_graph=types_of_hotel_bookings.plot.bar()
plotting_graph.set_title('number of bookings hotel wise')
# Out:
# Text(0.5, 1.0, 'number of bookings hotel wise')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the specific bar chart because:
#
# :i wanted to clearly visualise my data respective to number of bookings according to hotel wise.
#
# "i wanted to facilitate comparisons by an eye view.
#
# :in order to gain insights in an easier way,
#
# :so as to make data more informative and user friendly.
#
# :in order to reduce time required in manual comparison.
#
# :to make vocal results and plans more informative.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The above bar graph had been very useful in providing insights related to hotel bookings,i found the following true factual information:
#
# ::Here the number of bookings in terms of hotels are very divergent.
#
# :: bookings recorded in city hotel is approx 2 times that of resort hotel
#
# ::city hotel showed great number of bookings in particular time period ,
#
# ::resort hotel is lagging behind in terms of bookings.
#
# ::comparison is easy as both hotels have divergent bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# YES, i have gained insights from the graph ,which will facilitate me in drawing positive impact for my business:
#
# ::i have found that city hotel is demanding among customers,so taking decision in the aspect  of increasing supply for same  will create positive impact
#
# ::i have found that resort hotel are too behind and capacity must be unutilised so supply can be shrinked.
#
# ;:the avai;ibi;ity of room can be manipulated.
#
# ::reacting according to demand will improve business.
#
# NEGATIVE GROWTH CAN BE BECAUSE OF:
#
# ::less availabilty of city hotel
#
# ::or less availability of resort hotel

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#no.of bookings in every year
yearwise_bookings=mydf.groupby('arrival_date_year')['unique_id'].count()
pie_chart=yearwise_bookings.plot.pie()
pie_chart.set_title('yearwise bookings')
# Out:
# Text(0.5, 1.0, 'yearwise bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the specific pie chart because:
#
# :i wanted to clearly visualise my data respective to number of bookings according to year wise.
#
# "i wanted to facilitate comparisons by an eye view.
#
# :in order to gain insights in an easier way,
#
# :so as to make data more informative and user friendly.
#
# :in order to reduce time required in manual comparison.
#
# :to make vocal results and plans more informative.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The above pie graph had been very useful in providing insights related to yearwise bookings,i found the following true factual information:
#
# ::Here the number of bookings in terms of years  are n not very divergent.
#
# :: bookings recorded in 2016 took high jump from 2015
#
# ::yaer 2016 showed great number of bookings in particular time period ,
#
# ::2015,2017 legged behind in terms of bookings.
#
# ::comparison is easy as all years have divergent bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# YES, i have gained insights from the graph ,which will facilitate me in drawing positive impact for my business:
#
# ::i have found that 2016is demanding among customers,so taking decision in the aspect of analysing strengths in that year will create positive impact
#
# ::i have found that 2015,2017 were idle years and some negative parameters existed which didnt give expected demand.
#
# ;:the bookings can be manipulated by directing the strengths recorded ibn 2016 ..
#
# ::reacting according to demand will improve business.
#
# NEGATIVE GROWTH CAN BE BECAUSE OF:
#
# ::not reacting better to demands.
#
# ::or less availability thereon

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# monthwise bookings

monthwise_bookings=mydf.groupby(['hotel','arrival_date_month'])['unique_id'].count().unstack()
monthwise_bookings
create_chart=monthwise_bookings.plot.area()
create_chart.set_title('monthwise hotel bookings')
# Out:
# Text(0.5, 1.0, 'monthwise hotel bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the specific area chart because:
#
# :i wanted to clearly visualise my data respective to number of bookings according to month and hotel  wise.
#
# "i wanted to facilitate comparisons by an eye view.
#
# :in order to gain insights in an easier way,
#
# :so as to make data more informative and user friendly.
#
# :in order to reduce time required in manual comparison.
#
# :to make vocal results and plans more informative.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# he above area graph had been very useful in providing insights related to month and hotel wise bookings,i found the following true factual information:
#
# ::Here the number of bookings in terms of months are  not very divergent.
#
# :: bookings recorded in SEPTEMBER,JULY,MAY  took high jump
#
# ::MONTHS SEP.,JULY,MAY showed great number of bookings in particular time period ,
#
# : JANUARY,OCTOBER,DECEMBER legged behind in terms of bookings.
#
# ::comparison is easy as all months have divergent bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# ES, i have gained insights from the graph ,which will facilitate me in drawing positive impact for my business:
#
# ::i have found that september ,july,may are demanding among customers,so taking decision in the aspect of analysing strengths in those months  will create positive impact
#
# ::i have found that december,january  were idle months  and some negative parameters existed which didnt give expected demand.
#
# ;:the bookings can be manipulated by directing the strengths recorded in september ..
#
# ::reacting according to demand will improve business.
#
# NEGATIVE GROWTH CAN BE BECAUSE OF:
#
# ::not reacting better to demands.
#
# ::or less availability thereon

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code\

# age groupm of customers

age_group=mydf[['adults','children','babies']].sum()
plot_agewise_bookings=age_group.plot.bar()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the specific bar chart because:
#
# :i wanted to clearly visualise my data respective to number of bookings according to age group.
#
# "i wanted to facilitate comparisons by an eye view.
#
# :in order to gain insights in an easier way,
#
# :so as to make data more informative and user friendly.
#
# :in order to reduce time required in manual comparison.
#
# :to make vocal results and plans more informative.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The above bar graph had been very useful in providing insights related to yearwise bookings,i found the following true factual information:
#
# ::Here the number of bookings in terms of age group is  very divergent.
#
# :: bookings recorded by adults took high jump
#
# ::adults  showed great number of bookings in particular time period ,
#
# ::children,babies legged behind in terms of bookings.
#
# ::comparison is easy as all age group have divergent bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# YES, i have gained insights from the graph ,which will facilitate me in drawing positive impact for my business:
#
# ::i have found that  adults are most frequent  among customers,so taking decision in the aspect of analysing strengths in that year will create positive impact
#
# ::i have found that children and babies are insignificant and some negative parameters existed which didnt give expected demand.
#
# ;:the bookings can be manipulated by directing the strengths recorded by adults ..
#
# ::reacting according to demand will improve business.
#
# NEGATIVE GROWTH CAN BE BECAUSE OF:
#
# ::not reacting better to demands.
#
# ::or less availability thereon

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#country wise bookings
country_wise_bookings=mydf.groupby('country')['unique_id'].count()
chart_of_country_bookings=country_wise_bookings.plot.pie()
chart_of_country_bookings.set_title('countrywise bookings')
# Out:
# Text(0.5, 1.0, 'countrywise bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the specific pie chart because:
#
# :i wanted to clearly visualise my data respective to number of bookings according to country  and hotel wise.
#
# "i wanted to facilitate comparisons by an eye view.
#
# :in order to gain insights in an easier way,
#
# :so as to make data more informative and user friendly.
#
# :in order to reduce time required in manual comparison.
#
# :to make vocal results and plans more informative.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The above pie graph had been very useful in providing insights related to COUNTRYWISE bookings,i found the following true factual information:
#
# ::Here the number of bookings in terms of COUNTRIES is very divergent.
#
# :: bookings recorded by PRTGBR,FRA,ESP took high jump
#
# ::PRT showed great number of bookings in particular time period ,
#
# ::MOST OF THE COUNTRIES legged behind in terms of bookings.
#
# ::comparison is easy as all COUNTRIES  have divergent bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# YES, i have gained insights from the graph ,which will facilitate me in drawing positive impact for my business:
#
# ::i have found that PRT,ERA,DEF are most frequent among customers,so taking decision in the aspect of analysing strengths in thOSE countries  will create positive impact
#
# ::i have found that lot of countries  are insignificant and some negative parameters existed which didnt give expected demand.
#
# ;:the bookings can be manipulated by directing the strengths recorded by few countries ..
#
# ::reacting according to demand will improve business.
#
# NEGATIVE GROWTH CAN BE BECAUSE OF:
#
# ::not reacting better to demands.
#
# ::or less availability thereon

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# room type booking visualisation

room_type_bookings=mydf.groupby(['hotel','assigned_room_type'])['unique_id'].count().unstack()
plot_room_type_bookings=room_type_bookings.plot.bar()

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#  I chose the specific bar chart because:
#
# :i wanted to clearly visualise my data respective to number of bookings according to hotel and room type
#
# "i wanted to facilitate comparisons by an eye view.
#
# :in order to gain insights in an easier way,
#
# :so as to make data more informative and user friendly.
#
# :in order to reduce time required in manual comparison.
#
# :to make vocal results and plans more informative.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The above pie graph had been very useful in providing insights related to room type bookings,i found the following true factual information:
#
# ::Here the number of bookings in terms of room type is very divergent.
#
# :: bookings recorded by room type A,D,E took high jump
#
# ::ROOM TYPE A showed great number of bookings in particular time period ,
#
# ::MOST OF THE ROOM TYPE LIKE H,K,L,F legged behind in terms of bookings.
#
# ::comparison is easy as all ROOM TYPE have divergent bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# YES, i have gained insights from the graph ,which will facilitate me in drawing positive impact for my business:
#
# ::i have found that ROOM TYPE A,D,E are most frequent among customers,so taking decision in the aspect of analysing strengths in thOSE room type will create positive impact
#
# ::i have found that lot of room types are insignificant and some negative parameters existed which didnt give expected demand.
#
# ;:the bookings can be manipulated by directing the strengths recorded by few room types.
#
# ::reacting according to demand will improve business.
#
# NEGATIVE GROWTH CAN BE BECAUSE OF:
#
# ::not reacting better to demands.
#
# ::or less availability thereon

# %% [markdown]
# #### Chart - 7 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
#finding relationship between variables

correlation_df=mydf.corr()
#made new datset which contain corre;lation between variables
mydf.corr()
#plotting the heatmap
sns.heatmap(correlation_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the specific correlation heatmap  chart because:
#
# :i wanted to clearly visualise my data respective to relation exist between any two variables.
#
# "i wanted to facilitate comparisons by an eye view.
#
# :in order to gain insights in an easier way,
#
# :so as to make data more informative and user friendly.
#
# :in order to reduce time required in manual comparison.
#
# :to make vocal results and plans more informative.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The insights found from the chart are as follows:
#
# :arrival date year abd arrival week are negatively correlated to eaqch other,
#
# :stays in week nights andb weekend nights are somehow positively related to some extent.
#
# ::lead time of bookings is somehow seen affecting other variables like number of adults,children ,stays in positive manner.
#
# :: most of the variables are independent ,thus does not impact others like week number,year,no.of babies etc.
#
# ::lead time is somehow seen affecting bookings

# %% [markdown]
# Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# YES,the positive insights have been found from the particular chart which will be affecting our business in a positive way:
#
# ::here we can manipulate lead time in order to make changes in most of the variables '
#
# :: lead time can somehow positively impact num ber of bookings.
#
# :: here for most of the variab les ,we have to work independently.
#
# YES,there are some negative impact of insights too:
#
# :: we for most of the variables ,manipulation is not possibles because of indepedency.

# %% [markdown]
# #### Chart - 8 - Pair Plot

# %%
# Pair Plot visualization code

sns.pairplot(mydf)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I chose the specific pairplot chart because:
#
# :i wanted to clearly visualise my data respective to relation exist between any two variables pairwise.
#
# "i wanted to facilitate comparisons by an eye view.
#
# :in order to gain insights in an easier way,
#
# :so as to make data more informative and user friendly.
#
# :in order to reduce time required in manual comparison.
#
# :to make vocal results and plans more informative.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The insights found from the chart are as follows:
#
# :arrival date year abd arrival week are negatively correlated to eaqch other,
#
# :stays in week nights andb weekend nights are somehow positively related to some extent.
#
# ::lead time of bookings is somehow seen affecting other variables like number of adults,children ,stays in positive manner.
#
# :: most of the variables are independent ,thus does not impact others like week number,year,no.of babies etc.
#
# ::lead time is somehow seen affecting bookings

# %% [markdown]
# Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# YES,the positive insights have been found from the particular chart which will be affecting our business in a positive way:
#
# ::here we can manipulate lead time in  order to make changes in most of the variables '
#
# :: lead time can somehow positively impact num ber of bookings.
#
# :: here for most of the variab les ,we have to work independently.
#
# YES,there are some negative impact of insights too:
#
# :: we for most of the variables ,manipulation is not possibles because of indepedency.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
